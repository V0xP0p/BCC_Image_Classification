# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import utils
import pandas as pd
import re
from parameters import labels, oh_labels, params
# Out:
# Main module did not execute

# %%
# Reorder the labels by taking into account the alphanumeric file order of the images.
# Needed preprocessing step to use tf.data.Dataset.
labels_list = utils.reorder_image_labels(params['image_path'], labels.iloc[:, 0].tolist(), index_start=1)

# %%
def str_to_numb(string_list):
    """

    :param string_list: list with of all the image numbers
    :return: numbers missing
    """
    number_list = []
    for string in string_list:
        number = re.findall(r'\d+', string)
        number_list.append(int(number[0].strip()))
    # number_list.sort()
    return number_list

# %%
image_paths = os.listdir(params['image_path'])
image_paths.sort(key=len)
img_numbers = str_to_numb(image_paths)
img_paths = []
j = 0
gegen = j + 1
for image in image_paths:
    if img_numbers[j] == gegen:
        img_paths.append(os.path.join(params['image_path'], image))
        gegen += 1
    else:
        print(f"Warning: picture {j + 1} is missing from the dataset")
        img_paths.append('None')
        img_paths.append(os.path.join(params['image_path'], image))
        gegen += 2
    j += 1

df = pd.DataFrame()
df['Image Paths'] = img_paths

# %%
images = df['Image Paths'].values

# %%
base_model = tf.keras.applications.resnet.ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=params['IMG_SHAPE'],
)
base_model.trainable = params['TRAINABLE']
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  175

# %%
if params['TRAINABLE'] and params['TUNE_LAYER'] is not None:
    # Freeze all the layers before the `fine_tune_at` layer
    for layer in params['TUNE_LAYER']:
      layer.trainable = False

# %%
def create_model(img_shape, class_num, lr=1e-5, metrics=None):

    preprocess_input = tf.keras.applications.resnet.preprocess_input

    inputs = tf.keras.Input(shape=img_shape)
    x = preprocess_input(inputs)
    x = base_model(x, training=params['TRAINABLE'])
    # x = tf.keras.layers.Dropout(params['DROPOUT'])(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(params['DROPOUT'])(x)
    # x = tf.keras.layers.Dense(512, activation='relu')(x)
    # x = tf.keras.layers.Dropout(0.2)(x)
    outputs = tf.keras.layers.Dense(class_num, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=tf.keras.losses.CategoricalCrossentropy(),
                  metrics=metrics)

    return model

def preprocess_dataset(imagepath, entries, labels, image_type='jpg', search_type='*', cache=True, batch_size=8, shuffle=True, augment=False, augmentation=None, prefetch=True):

    dataset = utils.ImageDataset(imagepath, entries=entries, labels=labels, image_type=image_type, search_type=search_type)
    dataset = dataset.create_image_dataset()
    dataset = utils.ImageDataset.performance_config(dataset, cache=cache, batch_size=batch_size, shuffle=shuffle, augment=augment, augmentation=augmentation, prefetch=prefetch)

    return dataset

def evaluate_image(model, imagepath, target_size=None):

    img = tf.keras.utils.load_img(imagepath, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array, verbose=0)
    score = tf.nn.softmax(predictions[0])

    return np.argmax(score), np.max(score)

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                              min_delta=1e-2,
                                              patience=5,
                                              verbose=1),
             tf.keras.callbacks.ModelCheckpoint(params['save_path'] + 'model/',
                                      save_best_only=True,
                                      verbose=0,
                                      save_weights_only=True),
             tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",
                                                  factor=0.1,
                                                  patience=3,
                                                  min_delta=1e-2)
            ]

data_augmentation = tf.keras.Sequential([tf.keras.layers.RandomFlip("horizontal_and_vertical"),
                                         tf.keras.layers.RandomRotation(0.5),
                                         tf.keras.layers.RandomZoom(0.1),
                                         tf.keras.layers.RandomContrast(0.3),
                                         tf.keras.layers.RandomBrightness(0.2)])

# %%
oh_list_labels = tf.keras.utils.to_categorical(labels_list, params['CLASS_NUMBER'])

# %%
if params['KFOLD']:
    # split the data to dev and test set
    outer_skf = utils.split_data(df,
                           labels_list,
                           split_strategy='StratifiedKFold',
                           n_splits=params['OUTER_SPLITS'],
                           shuffle=params['shuffle'],
                           random_state=None) #params['SEED'])
    # create a Logger object to record and display the values we need
    log = utils.Logger()
    experiment = 1
    # log the parameters used to json
    log.to_json(params['save_path'] + f'Experiment_{experiment}_parameters.json', params)
    model_history = {}
    # ensure use of gpu
    with tf.device("gpu:0"):

        for (dev_idx, test_idx), i in outer_skf:

            print(f"\nStarting Training on Outer Fold {i+1}/{params['OUTER_SPLITS']}.")
            print("===========================================")
            # create the inner splits
            #labels_array = np.array(labels_list)[dev_idx.astype(int)]

            inner_skf = utils.split_data(df.loc[dev_idx, :],
                                   np.array(labels_list)[dev_idx.astype(int)],
                                   split_strategy='StratifiedKFold',
                                   n_splits=params['INNER_SPLITS'],
                                   shuffle=params['shuffle'],
                                   random_state=None) #params['SEED'])

            fold_history = []

            model_history[f"Fold_{i}_acc"] = []

            test = preprocess_dataset(params['image_path'],
                             images[test_idx],
                             oh_list_labels[test_idx, :],
                             batch_size=params['BATCH_SIZE'],
                             shuffle=params['shuffle'],
                             cache=params['cache'])

            for (train_idx, val_idx), j in inner_skf:


                train = preprocess_dataset(params['image_path'],
                               images[train_idx],
                               oh_list_labels[train_idx, :],
                               batch_size=params['BATCH_SIZE'],
                               cache=params['cache'],
                               shuffle=params['shuffle'],
                               augment=params['augment'],
                               augmentation=data_augmentation)

                val = preprocess_dataset(params['image_path'],
                             images[val_idx],
                             oh_list_labels[val_idx, :],
                             batch_size=params['BATCH_SIZE'],
                             shuffle=params['shuffle'],
                             cache=params['cache'])

                model = create_model(params['IMG_SHAPE'], params['CLASS_NUMBER'], params['LR'], metrics=params['metrics'])


                print(f"\nStarting Training on Inner Fold {j+1}/{params['INNER_SPLITS']}.")
                print("===========================================")

                fold_hist = model.fit(train,
                                      epochs=params['MAX_EPOCHS'],
                                      validation_data=val,
                                      callbacks=callbacks)


                # create a list of the metrics names used
                metrics = ["val_" + metric.lower() for metric in params['metrics']]
                # create a list of the metrics values
                metrics_values = [np.amax(fold_hist.history[metric]) for metric in metrics]
                # add the metrics and their labels to a dictionary
                fold_metrics = {key:val for key, val in zip(metrics, metrics_values ) }
                # Log the train metrics to an excel file and retrieve the experiment number
                experiment = log.to_excel(params['save_path'] + 'results.xlsx', fold_metrics)
                # change the type of the training metrics to float so they can be serialized in json
                model_history[f"Fold_{i}.{j}_hist"] = {key: list(map(float, val)) for key, val in fold_hist.history.items()}

                model_history[f"Fold_{i}.{j}_acc"] = []

                model_history[f"Fold_{i}.{j}_test"] = dict(zip(model.metrics_names, model.evaluate(test)))


                print(f"          Fold {i}.{j} Results")
                print("**|" + "-"* 30 + "|**")
                # m = tf.keras.metrics.Accuracy()
                # m.update_state(model_history[f"Fold_{i}.{j}_preds"], labels.loc[test_idx, :])
                accuracy = model_history[f"Fold_{i}.{j}_test"]['categorical_accuracy']
                model_history[f"Fold_{i}.{j}_acc"].append(accuracy)
                print(f"  |       Accuracy = {accuracy:.3f}       |")


            acc_avg = np.mean(model_history[f"Fold_{i}.{j}_acc"])
            acc_std = np.std(model_history[f"Fold_{i}.{j}_acc"])

            model_history[f"Fold_{i}_acc"] = acc_avg
            model_history[f"Fold_{i}_std"] = model_history[f"Fold_{i}.{j}_acc"]

            print(f"\n            Fold {i} Averaged Results")
            print("**|" + "-"* 40 + "|**")
            print(f"  |          Mean Accuracy = {acc_avg:.3f}         |")
            print(f"  |      Mean Standard Deviation = {acc_std:.3f}   |")

    # Log the model training history to json
    log.to_json(params['save_path'] + f'Experiment_{experiment}_history.json', model_history)
# Out:
# Starting Training on Outer Fold 1/20.
# ===========================================
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
#
# Starting Training on Inner Fold 1/5.
# ===========================================
# Epoch 1/100
# 10/10 [==============================] - 7s 359ms/step - loss: 2.3737 - categorical_accuracy: 0.1972 - precision: 0.1856 - recall: 0.1659 - auc: 0.3499 - val_loss: 2.0211 - val_categorical_accuracy: 0.1125 - val_precision: 0.0598 - val_recall: 0.0437 - val_auc: 0.2197 - lr: 1.0000e-05
# Epoch 2/100
# 10/10 [==============================] - 2s 167ms/step - loss: 2.0846 - categorical_accuracy: 0.2551 - precision: 0.2629 - recall: 0.2238 - auc: 0.4224 - val_loss: 1.8660 - val_categorical_accuracy: 0.1375 - val_precision: 0.1062 - val_recall: 0.0750 - val_auc: 0.2693 - lr: 1.0000e-05
# Epoch 3/100
# 10/10 [==============================] - 2s 174ms/step - loss: 1.9966 - categorical_accuracy: 0.2613 - precision: 0.2559 - recall: 0.2222 - auc: 0.4270 - val_loss: 1.7172 - val_categorical_accuracy: 0.1875 - val_precision: 0.1296 - val_recall: 0.0875 - val_auc: 0.3240 - lr: 1.0000e-05
# Epoch 4/100
# 10/10 [==============================] - 2s 165ms/step - loss: 1.9619 - categorical_accuracy: 0.2833 - precision: 0.2732 - recall: 0.2347 - auc: 0.4445 - val_loss: 1.5730 - val_categorical_accuracy: 0.2375 - val_precision: 0.2054 - val_recall: 0.1437 - val_auc: 0.3857 - lr: 1.0000e-05
# Epoch 5/100
# 10/10 [==============================] - 2s 167ms/step - loss: 1.7332 - categorical_accuracy: 0.3208 - precision: 0.3201 - recall: 0.2786 - auc: 0.5091 - val_loss: 1.4383 - val_categorical_accuracy: 0.2688 - val_precision: 0.2830 - val_recall: 0.1875 - val_auc: 0.4529 - lr: 1.0000e-05
# Epoch 6/100
# 10/10 [==============================] - 3s 187ms/step - loss: 1.6745 - categorical_accuracy: 0.3552 - precision: 0.3539 - recall: 0.3146 - auc: 0.5328 - val_loss: 1.3129 - val_categorical_accuracy: 0.3500 - val_precision: 0.3524 - val_recall: 0.2313 - val_auc: 0.5229 - lr: 1.0000e-05
# Epoch 7/100
# 10/10 [==============================] - 2s 163ms/step - loss: 1.6411 - categorical_accuracy: 0.3787 - precision: 0.3821 - recall: 0.3271 - auc: 0.5463 - val_loss: 1.1954 - val_categorical_accuracy: 0.4000 - val_precision: 0.4037 - val_recall: 0.2750 - val_auc: 0.5915 - lr: 1.0000e-05
# Epoch 8/100
# 10/10 [==============================] - 2s 163ms/step - loss: 1.4795 - categorical_accuracy: 0.3991 - precision: 0.4188 - recall: 0.3552 - auc: 0.5824 - val_loss: 1.0851 - val_categorical_accuracy: 0.4688 - val_precision: 0.4690 - val_recall: 0.3313 - val_auc: 0.6594 - lr: 1.0000e-05
# Epoch 9/100
# 10/10 [==============================] - 2s 164ms/step - loss: 1.3583 - categorical_accuracy: 0.4178 - precision: 0.4327 - recall: 0.3725 - auc: 0.6277 - val_loss: 0.9841 - val_categorical_accuracy: 0.5375 - val_precision: 0.5714 - val_recall: 0.4000 - val_auc: 0.7199 - lr: 1.0000e-05
# Epoch 10/100
# 10/10 [==============================] - 2s 167ms/step - loss: 1.3971 - categorical_accuracy: 0.4444 - precision: 0.4541 - recall: 0.4022 - auc: 0.6199 - val_loss: 0.8909 - val_categorical_accuracy: 0.5813 - val_precision: 0.6555 - val_recall: 0.4875 - val_auc: 0.7756 - lr: 1.0000e-05
# Epoch 11/100
# 10/10 [==============================] - 2s 166ms/step - loss: 1.3396 - categorical_accuracy: 0.4570 - precision: 0.4720 - recall: 0.4085 - auc: 0.6476 - val_loss: 0.8042 - val_categorical_accuracy: 0.6438 - val_precision: 0.7107 - val_recall: 0.5375 - val_auc: 0.8248 - lr: 1.0000e-05
# Epoch 12/100
# 10/10 [==============================] - 2s 164ms/step - loss: 1.1907 - categorical_accuracy: 0.5133 - precision: 0.5339 - recall: 0.4679 - auc: 0.6976 - val_loss: 0.7258 - val_categorical_accuracy: 0.6750 - val_precision: 0.7638 - val_recall: 0.6062 - val_auc: 0.8656 - lr: 1.0000e-05
# Epoch 13/100
# 10/10 [==============================] - 2s 166ms/step - loss: 1.1543 - categorical_accuracy: 0.5149 - precision: 0.5210 - recall: 0.4664 - auc: 0.7053 - val_loss: 0.6537 - val_categorical_accuracy: 0.7063 - val_precision: 0.7939 - val_recall: 0.6500 - val_auc: 0.8989 - lr: 1.0000e-05
# Epoch 14/100
# 10/10 [==============================] - 2s 162ms/step - loss: 1.1220 - categorical_accuracy: 0.5258 - precision: 0.5554 - recall: 0.4867 - auc: 0.7195 - val_loss: 0.5888 - val_categorical_accuracy: 0.7688 - val_precision: 0.8281 - val_recall: 0.6625 - val_auc: 0.9250 - lr: 1.0000e-05
# Epoch 15/100
# 10/10 [==============================] - 2s 161ms/step - loss: 1.0043 - categorical_accuracy: 0.5775 - precision: 0.6049 - recall: 0.5368 - auc: 0.7659 - val_loss: 0.5314 - val_categorical_accuracy: 0.8250 - val_precision: 0.8722 - val_recall: 0.7250 - val_auc: 0.9435 - lr: 1.0000e-05
# Epoch 16/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.9633 - categorical_accuracy: 0.5884 - precision: 0.6076 - recall: 0.5477 - auc: 0.7792 - val_loss: 0.4796 - val_categorical_accuracy: 0.8625 - val_precision: 0.9248 - val_recall: 0.7688 - val_auc: 0.9585 - lr: 1.0000e-05
# Epoch 17/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.9278 - categorical_accuracy: 0.6025 - precision: 0.6290 - recall: 0.5571 - auc: 0.7920 - val_loss: 0.4335 - val_categorical_accuracy: 0.8938 - val_precision: 0.9424 - val_recall: 0.8188 - val_auc: 0.9690 - lr: 1.0000e-05
# Epoch 18/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.8539 - categorical_accuracy: 0.6228 - precision: 0.6483 - recall: 0.5884 - auc: 0.8138 - val_loss: 0.3912 - val_categorical_accuracy: 0.9187 - val_precision: 0.9514 - val_recall: 0.8562 - val_auc: 0.9769 - lr: 1.0000e-05
# Epoch 19/100
# 10/10 [==============================] - 2s 166ms/step - loss: 0.8113 - categorical_accuracy: 0.6275 - precision: 0.6579 - recall: 0.5869 - auc: 0.8304 - val_loss: 0.3535 - val_categorical_accuracy: 0.9375 - val_precision: 0.9597 - val_recall: 0.8938 - val_auc: 0.9813 - lr: 1.0000e-05
# Epoch 20/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.7492 - categorical_accuracy: 0.6948 - precision: 0.7081 - recall: 0.6604 - auc: 0.8577 - val_loss: 0.3211 - val_categorical_accuracy: 0.9500 - val_precision: 0.9608 - val_recall: 0.9187 - val_auc: 0.9855 - lr: 1.0000e-05
# Epoch 21/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.7275 - categorical_accuracy: 0.6901 - precision: 0.7080 - recall: 0.6526 - auc: 0.8606 - val_loss: 0.2917 - val_categorical_accuracy: 0.9625 - val_precision: 0.9618 - val_recall: 0.9438 - val_auc: 0.9885 - lr: 1.0000e-05
# Epoch 22/100
# 10/10 [==============================] - 2s 165ms/step - loss: 0.6863 - categorical_accuracy: 0.7167 - precision: 0.7380 - recall: 0.6745 - auc: 0.8731 - val_loss: 0.2651 - val_categorical_accuracy: 0.9688 - val_precision: 0.9742 - val_recall: 0.9438 - val_auc: 0.9908 - lr: 1.0000e-05
# Epoch 23/100
# 10/10 [==============================] - 3s 173ms/step - loss: 0.6661 - categorical_accuracy: 0.7074 - precision: 0.7342 - recall: 0.6745 - auc: 0.8832 - val_loss: 0.2411 - val_categorical_accuracy: 0.9750 - val_precision: 0.9744 - val_recall: 0.9500 - val_auc: 0.9927 - lr: 1.0000e-05
# Epoch 24/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.6305 - categorical_accuracy: 0.7308 - precision: 0.7483 - recall: 0.7027 - auc: 0.8963 - val_loss: 0.2199 - val_categorical_accuracy: 0.9750 - val_precision: 0.9745 - val_recall: 0.9563 - val_auc: 0.9938 - lr: 1.0000e-05
# Epoch 25/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.5506 - categorical_accuracy: 0.7574 - precision: 0.7966 - recall: 0.7293 - auc: 0.9181 - val_loss: 0.2012 - val_categorical_accuracy: 0.9750 - val_precision: 0.9750 - val_recall: 0.9750 - val_auc: 0.9950 - lr: 1.0000e-05
# Epoch 26/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.5859 - categorical_accuracy: 0.7480 - precision: 0.7755 - recall: 0.7136 - auc: 0.9081 - val_loss: 0.1841 - val_categorical_accuracy: 0.9750 - val_precision: 0.9873 - val_recall: 0.9750 - val_auc: 0.9959 - lr: 1.0000e-05
# Epoch 27/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.5562 - categorical_accuracy: 0.7715 - precision: 0.7963 - recall: 0.7402 - auc: 0.9160 - val_loss: 0.1685 - val_categorical_accuracy: 0.9875 - val_precision: 0.9873 - val_recall: 0.9750 - val_auc: 0.9966 - lr: 1.0000e-05
# Epoch 28/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.4972 - categorical_accuracy: 0.7793 - precision: 0.7983 - recall: 0.7496 - auc: 0.9327 - val_loss: 0.1546 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9974 - lr: 1.0000e-05
# Epoch 29/100
# 10/10 [==============================] - 2s 165ms/step - loss: 0.4576 - categorical_accuracy: 0.8263 - precision: 0.8430 - recall: 0.7981 - auc: 0.9430 - val_loss: 0.1422 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9981 - lr: 1.0000e-05
# Epoch 30/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.4548 - categorical_accuracy: 0.8153 - precision: 0.8433 - recall: 0.7919 - auc: 0.9435 - val_loss: 0.1310 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9984 - lr: 1.0000e-05
# Epoch 31/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.4135 - categorical_accuracy: 0.8404 - precision: 0.8651 - recall: 0.8028 - auc: 0.9551 - val_loss: 0.1211 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9988 - lr: 1.0000e-05
# Epoch 32/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.4120 - categorical_accuracy: 0.8372 - precision: 0.8484 - recall: 0.8232 - auc: 0.9538 - val_loss: 0.1119 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9992 - lr: 1.0000e-05
# Epoch 33/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.4327 - categorical_accuracy: 0.8232 - precision: 0.8439 - recall: 0.7950 - auc: 0.9488 - val_loss: 0.1036 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9994 - lr: 1.0000e-05
# Epoch 34/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.4087 - categorical_accuracy: 0.8232 - precision: 0.8445 - recall: 0.8075 - auc: 0.9548 - val_loss: 0.0959 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9996 - lr: 1.0000e-05
# Epoch 35/100
# 10/10 [==============================] - 3s 187ms/step - loss: 0.3761 - categorical_accuracy: 0.8607 - precision: 0.8917 - recall: 0.8372 - auc: 0.9635 - val_loss: 0.0890 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9997 - lr: 1.0000e-05
# Epoch 36/100
# 10/10 [==============================] - 2s 165ms/step - loss: 0.3830 - categorical_accuracy: 0.8388 - precision: 0.8564 - recall: 0.8216 - auc: 0.9609 - val_loss: 0.0827 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9998 - lr: 1.0000e-05
# Epoch 37/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.3658 - categorical_accuracy: 0.8576 - precision: 0.8681 - recall: 0.8341 - auc: 0.9645 - val_loss: 0.0770 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9998 - lr: 1.0000e-05
# Epoch 38/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.3065 - categorical_accuracy: 0.8951 - precision: 0.9088 - recall: 0.8732 - auc: 0.9769 - val_loss: 0.0718 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 39/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.3153 - categorical_accuracy: 0.8764 - precision: 0.8892 - recall: 0.8670 - auc: 0.9740 - val_loss: 0.0672 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 40/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.3185 - categorical_accuracy: 0.8779 - precision: 0.8956 - recall: 0.8592 - auc: 0.9737 - val_loss: 0.0628 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 41/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.3025 - categorical_accuracy: 0.8889 - precision: 0.9048 - recall: 0.8623 - auc: 0.9769 - val_loss: 0.0586 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 42/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.2914 - categorical_accuracy: 0.8826 - precision: 0.9023 - recall: 0.8670 - auc: 0.9789 - val_loss: 0.0550 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 43/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.2832 - categorical_accuracy: 0.8983 - precision: 0.9109 - recall: 0.8795 - auc: 0.9795 - val_loss: 0.0516 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 44/100
# 10/10 [==============================] - 3s 169ms/step - loss: 0.2688 - categorical_accuracy: 0.9045 - precision: 0.9145 - recall: 0.8873 - auc: 0.9820 - val_loss: 0.0483 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 45/100
# 10/10 [==============================] - 2s 167ms/step - loss: 0.2294 - categorical_accuracy: 0.9202 - precision: 0.9416 - recall: 0.9077 - auc: 0.9891 - val_loss: 0.0456 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 46/100
# 10/10 [==============================] - 2s 177ms/step - loss: 0.2417 - categorical_accuracy: 0.9061 - precision: 0.9196 - recall: 0.8951 - auc: 0.9865 - val_loss: 0.0430 - val_categorical_accuracy: 0.9875 - val_precision: 0.9937 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 47/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.2402 - categorical_accuracy: 0.9171 - precision: 0.9203 - recall: 0.9030 - auc: 0.9867 - val_loss: 0.0406 - val_categorical_accuracy: 0.9875 - val_precision: 1.0000 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 48/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.2457 - categorical_accuracy: 0.9155 - precision: 0.9277 - recall: 0.9030 - auc: 0.9850 - val_loss: 0.0403 - val_categorical_accuracy: 0.9875 - val_precision: 1.0000 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-06
# Epoch 49/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.2534 - categorical_accuracy: 0.9108 - precision: 0.9181 - recall: 0.8951 - auc: 0.9843 - val_loss: 0.0401 - val_categorical_accuracy: 0.9875 - val_precision: 1.0000 - val_recall: 0.9875 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 49: early stopping
#
# Logged the following variables:
# ------------------------------
# val_categorical_accuracy: 0.99
# val_precision: 1.00
# val_recall: 0.99
# val_auc: 1.00
# 1/1 [==============================] - 1s 819ms/step - loss: 0.0336 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#           Fold 0.0 Results
# **|------------------------------|**
#   |       Accuracy = 1.000       |
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
#
# Starting Training on Inner Fold 2/5.
# ===========================================
# Epoch 1/100
# 10/10 [==============================] - 7s 310ms/step - loss: 3.0570 - categorical_accuracy: 0.1205 - precision: 0.1123 - recall: 0.1017 - auc: 0.2535 - val_loss: 2.8352 - val_categorical_accuracy: 0.0500 - val_precision: 0.0403 - val_recall: 0.0375 - val_auc: 0.1721 - lr: 1.0000e-05
# Epoch 2/100
# 10/10 [==============================] - 2s 134ms/step - loss: 2.9983 - categorical_accuracy: 0.1111 - precision: 0.1002 - recall: 0.0908 - auc: 0.2482 - val_loss: 2.6700 - val_categorical_accuracy: 0.0562 - val_precision: 0.0467 - val_recall: 0.0437 - val_auc: 0.1986 - lr: 1.0000e-05
# Epoch 3/100
# 10/10 [==============================] - 2s 125ms/step - loss: 2.7282 - categorical_accuracy: 0.1518 - precision: 0.1439 - recall: 0.1268 - auc: 0.2886 - val_loss: 2.5103 - val_categorical_accuracy: 0.0562 - val_precision: 0.0537 - val_recall: 0.0500 - val_auc: 0.2251 - lr: 1.0000e-05
# Epoch 4/100
# 10/10 [==============================] - 2s 127ms/step - loss: 2.5939 - categorical_accuracy: 0.1972 - precision: 0.1741 - recall: 0.1534 - auc: 0.3319 - val_loss: 2.3561 - val_categorical_accuracy: 0.0625 - val_precision: 0.0544 - val_recall: 0.0500 - val_auc: 0.2532 - lr: 1.0000e-05
# Epoch 5/100
# 10/10 [==============================] - 2s 125ms/step - loss: 2.3817 - categorical_accuracy: 0.2050 - precision: 0.1920 - recall: 0.1659 - auc: 0.3591 - val_loss: 2.2082 - val_categorical_accuracy: 0.0688 - val_precision: 0.0685 - val_recall: 0.0625 - val_auc: 0.2854 - lr: 1.0000e-05
# Epoch 6/100
# 10/10 [==============================] - 2s 128ms/step - loss: 2.4999 - categorical_accuracy: 0.2097 - precision: 0.1941 - recall: 0.1737 - auc: 0.3595 - val_loss: 2.0642 - val_categorical_accuracy: 0.0875 - val_precision: 0.0764 - val_recall: 0.0688 - val_auc: 0.3199 - lr: 1.0000e-05
# Epoch 7/100
# 10/10 [==============================] - 2s 133ms/step - loss: 2.2557 - categorical_accuracy: 0.2269 - precision: 0.2165 - recall: 0.1925 - auc: 0.3833 - val_loss: 1.9249 - val_categorical_accuracy: 0.1187 - val_precision: 0.1034 - val_recall: 0.0938 - val_auc: 0.3543 - lr: 1.0000e-05
# Epoch 8/100
# 10/10 [==============================] - 2s 124ms/step - loss: 2.3077 - categorical_accuracy: 0.2426 - precision: 0.2406 - recall: 0.2113 - auc: 0.3967 - val_loss: 1.7915 - val_categorical_accuracy: 0.1562 - val_precision: 0.1310 - val_recall: 0.1187 - val_auc: 0.3902 - lr: 1.0000e-05
# Epoch 9/100
# 10/10 [==============================] - 2s 128ms/step - loss: 2.0385 - categorical_accuracy: 0.2692 - precision: 0.2677 - recall: 0.2363 - auc: 0.4376 - val_loss: 1.6628 - val_categorical_accuracy: 0.1625 - val_precision: 0.1489 - val_recall: 0.1312 - val_auc: 0.4289 - lr: 1.0000e-05
# Epoch 10/100
# 10/10 [==============================] - 2s 126ms/step - loss: 2.0778 - categorical_accuracy: 0.2864 - precision: 0.2795 - recall: 0.2520 - auc: 0.4455 - val_loss: 1.5396 - val_categorical_accuracy: 0.1750 - val_precision: 0.1778 - val_recall: 0.1500 - val_auc: 0.4688 - lr: 1.0000e-05
# Epoch 11/100
# 10/10 [==============================] - 2s 124ms/step - loss: 1.8321 - categorical_accuracy: 0.3255 - precision: 0.3315 - recall: 0.2879 - auc: 0.5055 - val_loss: 1.4258 - val_categorical_accuracy: 0.2188 - val_precision: 0.2197 - val_recall: 0.1813 - val_auc: 0.5096 - lr: 1.0000e-05
# Epoch 12/100
# 10/10 [==============================] - 2s 124ms/step - loss: 1.8083 - categorical_accuracy: 0.3224 - precision: 0.3387 - recall: 0.2973 - auc: 0.5157 - val_loss: 1.3190 - val_categorical_accuracy: 0.2688 - val_precision: 0.2593 - val_recall: 0.2188 - val_auc: 0.5511 - lr: 1.0000e-05
# Epoch 13/100
# 10/10 [==============================] - 2s 124ms/step - loss: 1.7483 - categorical_accuracy: 0.3521 - precision: 0.3477 - recall: 0.3036 - auc: 0.5251 - val_loss: 1.2173 - val_categorical_accuracy: 0.3125 - val_precision: 0.3000 - val_recall: 0.2438 - val_auc: 0.5963 - lr: 1.0000e-05
# Epoch 14/100
# 10/10 [==============================] - 2s 125ms/step - loss: 1.5844 - categorical_accuracy: 0.3865 - precision: 0.4011 - recall: 0.3584 - auc: 0.5727 - val_loss: 1.1224 - val_categorical_accuracy: 0.3938 - val_precision: 0.3548 - val_recall: 0.2750 - val_auc: 0.6402 - lr: 1.0000e-05
# Epoch 15/100
# 10/10 [==============================] - 2s 124ms/step - loss: 1.5737 - categorical_accuracy: 0.3944 - precision: 0.4042 - recall: 0.3631 - auc: 0.5928 - val_loss: 1.0352 - val_categorical_accuracy: 0.4500 - val_precision: 0.4365 - val_recall: 0.3438 - val_auc: 0.6824 - lr: 1.0000e-05
# Epoch 16/100
# 10/10 [==============================] - 2s 129ms/step - loss: 1.4302 - categorical_accuracy: 0.4444 - precision: 0.4485 - recall: 0.4022 - auc: 0.6315 - val_loss: 0.9550 - val_categorical_accuracy: 0.5125 - val_precision: 0.5152 - val_recall: 0.4250 - val_auc: 0.7237 - lr: 1.0000e-05
# Epoch 17/100
# 10/10 [==============================] - 2s 129ms/step - loss: 1.3043 - categorical_accuracy: 0.5039 - precision: 0.5158 - recall: 0.4585 - auc: 0.6772 - val_loss: 0.8818 - val_categorical_accuracy: 0.5562 - val_precision: 0.5672 - val_recall: 0.4750 - val_auc: 0.7612 - lr: 1.0000e-05
# Epoch 18/100
# 10/10 [==============================] - 2s 132ms/step - loss: 1.3526 - categorical_accuracy: 0.4664 - precision: 0.4789 - recall: 0.4257 - auc: 0.6552 - val_loss: 0.8128 - val_categorical_accuracy: 0.6062 - val_precision: 0.6043 - val_recall: 0.5250 - val_auc: 0.7965 - lr: 1.0000e-05
# Epoch 19/100
# 10/10 [==============================] - 2s 123ms/step - loss: 1.2047 - categorical_accuracy: 0.5055 - precision: 0.5248 - recall: 0.4632 - auc: 0.6998 - val_loss: 0.7488 - val_categorical_accuracy: 0.6250 - val_precision: 0.6414 - val_recall: 0.5813 - val_auc: 0.8303 - lr: 1.0000e-05
# Epoch 20/100
# 10/10 [==============================] - 2s 128ms/step - loss: 1.1450 - categorical_accuracy: 0.5352 - precision: 0.5494 - recall: 0.4961 - auc: 0.7265 - val_loss: 0.6899 - val_categorical_accuracy: 0.6625 - val_precision: 0.6761 - val_recall: 0.6000 - val_auc: 0.8585 - lr: 1.0000e-05
# Epoch 21/100
# 10/10 [==============================] - 2s 125ms/step - loss: 1.1264 - categorical_accuracy: 0.5493 - precision: 0.5756 - recall: 0.5243 - auc: 0.7362 - val_loss: 0.6370 - val_categorical_accuracy: 0.6938 - val_precision: 0.7357 - val_recall: 0.6438 - val_auc: 0.8823 - lr: 1.0000e-05
# Epoch 22/100
# 10/10 [==============================] - 2s 123ms/step - loss: 1.0679 - categorical_accuracy: 0.5696 - precision: 0.5793 - recall: 0.5258 - auc: 0.7469 - val_loss: 0.5875 - val_categorical_accuracy: 0.7375 - val_precision: 0.7676 - val_recall: 0.6812 - val_auc: 0.9028 - lr: 1.0000e-05
# Epoch 23/100
# 10/10 [==============================] - 2s 128ms/step - loss: 0.9205 - categorical_accuracy: 0.6182 - precision: 0.6498 - recall: 0.5837 - auc: 0.8017 - val_loss: 0.5426 - val_categorical_accuracy: 0.7563 - val_precision: 0.7778 - val_recall: 0.7000 - val_auc: 0.9203 - lr: 1.0000e-05
# Epoch 24/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.9764 - categorical_accuracy: 0.6088 - precision: 0.6319 - recall: 0.5696 - auc: 0.7848 - val_loss: 0.5017 - val_categorical_accuracy: 0.8000 - val_precision: 0.8380 - val_recall: 0.7437 - val_auc: 0.9357 - lr: 1.0000e-05
# Epoch 25/100
# 10/10 [==============================] - 2s 128ms/step - loss: 0.9096 - categorical_accuracy: 0.6041 - precision: 0.6292 - recall: 0.5603 - auc: 0.8011 - val_loss: 0.4630 - val_categorical_accuracy: 0.8250 - val_precision: 0.8571 - val_recall: 0.7875 - val_auc: 0.9482 - lr: 1.0000e-05
# Epoch 26/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.9260 - categorical_accuracy: 0.6182 - precision: 0.6434 - recall: 0.5759 - auc: 0.8042 - val_loss: 0.4276 - val_categorical_accuracy: 0.8375 - val_precision: 0.8675 - val_recall: 0.8188 - val_auc: 0.9584 - lr: 1.0000e-05
# Epoch 27/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.8105 - categorical_accuracy: 0.6338 - precision: 0.6591 - recall: 0.5900 - auc: 0.8324 - val_loss: 0.3953 - val_categorical_accuracy: 0.8562 - val_precision: 0.8874 - val_recall: 0.8375 - val_auc: 0.9665 - lr: 1.0000e-05
# Epoch 28/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.7728 - categorical_accuracy: 0.6776 - precision: 0.7086 - recall: 0.6432 - auc: 0.8539 - val_loss: 0.3660 - val_categorical_accuracy: 0.8750 - val_precision: 0.8947 - val_recall: 0.8500 - val_auc: 0.9731 - lr: 1.0000e-05
# Epoch 29/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.7233 - categorical_accuracy: 0.7105 - precision: 0.7385 - recall: 0.6761 - auc: 0.8658 - val_loss: 0.3397 - val_categorical_accuracy: 0.8938 - val_precision: 0.9032 - val_recall: 0.8750 - val_auc: 0.9788 - lr: 1.0000e-05
# Epoch 30/100
# 10/10 [==============================] - 2s 131ms/step - loss: 0.6793 - categorical_accuracy: 0.7214 - precision: 0.7626 - recall: 0.6886 - auc: 0.8806 - val_loss: 0.3165 - val_categorical_accuracy: 0.8938 - val_precision: 0.9097 - val_recall: 0.8813 - val_auc: 0.9825 - lr: 1.0000e-05
# Epoch 31/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.6879 - categorical_accuracy: 0.7355 - precision: 0.7517 - recall: 0.6870 - auc: 0.8786 - val_loss: 0.2948 - val_categorical_accuracy: 0.9000 - val_precision: 0.9161 - val_recall: 0.8875 - val_auc: 0.9860 - lr: 1.0000e-05
# Epoch 32/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.7192 - categorical_accuracy: 0.7136 - precision: 0.7355 - recall: 0.6745 - auc: 0.8729 - val_loss: 0.2742 - val_categorical_accuracy: 0.9062 - val_precision: 0.9177 - val_recall: 0.9062 - val_auc: 0.9888 - lr: 1.0000e-05
# Epoch 33/100
# 10/10 [==============================] - 2s 132ms/step - loss: 0.6169 - categorical_accuracy: 0.7512 - precision: 0.7674 - recall: 0.7230 - auc: 0.9004 - val_loss: 0.2555 - val_categorical_accuracy: 0.9125 - val_precision: 0.9359 - val_recall: 0.9125 - val_auc: 0.9910 - lr: 1.0000e-05
# Epoch 34/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.6049 - categorical_accuracy: 0.7653 - precision: 0.7836 - recall: 0.7308 - auc: 0.9032 - val_loss: 0.2386 - val_categorical_accuracy: 0.9375 - val_precision: 0.9419 - val_recall: 0.9125 - val_auc: 0.9929 - lr: 1.0000e-05
# Epoch 35/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.5846 - categorical_accuracy: 0.7590 - precision: 0.7845 - recall: 0.7293 - auc: 0.9084 - val_loss: 0.2227 - val_categorical_accuracy: 0.9438 - val_precision: 0.9548 - val_recall: 0.9250 - val_auc: 0.9943 - lr: 1.0000e-05
# Epoch 36/100
# 10/10 [==============================] - 2s 131ms/step - loss: 0.5680 - categorical_accuracy: 0.7715 - precision: 0.7993 - recall: 0.7418 - auc: 0.9155 - val_loss: 0.2082 - val_categorical_accuracy: 0.9438 - val_precision: 0.9551 - val_recall: 0.9312 - val_auc: 0.9954 - lr: 1.0000e-05
# Epoch 37/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.5208 - categorical_accuracy: 0.7872 - precision: 0.8030 - recall: 0.7590 - auc: 0.9276 - val_loss: 0.1949 - val_categorical_accuracy: 0.9438 - val_precision: 0.9551 - val_recall: 0.9312 - val_auc: 0.9963 - lr: 1.0000e-05
# Epoch 38/100
# 10/10 [==============================] - 2s 127ms/step - loss: 0.5041 - categorical_accuracy: 0.7966 - precision: 0.8179 - recall: 0.7731 - auc: 0.9310 - val_loss: 0.1824 - val_categorical_accuracy: 0.9563 - val_precision: 0.9613 - val_recall: 0.9312 - val_auc: 0.9971 - lr: 1.0000e-05
# Epoch 39/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.4983 - categorical_accuracy: 0.8059 - precision: 0.8347 - recall: 0.7903 - auc: 0.9332 - val_loss: 0.1714 - val_categorical_accuracy: 0.9625 - val_precision: 0.9613 - val_recall: 0.9312 - val_auc: 0.9977 - lr: 1.0000e-05
# Epoch 40/100
# 10/10 [==============================] - 2s 139ms/step - loss: 0.4845 - categorical_accuracy: 0.8169 - precision: 0.8350 - recall: 0.7919 - auc: 0.9366 - val_loss: 0.1610 - val_categorical_accuracy: 0.9625 - val_precision: 0.9618 - val_recall: 0.9438 - val_auc: 0.9980 - lr: 1.0000e-05
# Epoch 41/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.4419 - categorical_accuracy: 0.8200 - precision: 0.8380 - recall: 0.8013 - auc: 0.9467 - val_loss: 0.1514 - val_categorical_accuracy: 0.9625 - val_precision: 0.9686 - val_recall: 0.9625 - val_auc: 0.9983 - lr: 1.0000e-05
# Epoch 42/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3997 - categorical_accuracy: 0.8435 - precision: 0.8696 - recall: 0.8247 - auc: 0.9566 - val_loss: 0.1431 - val_categorical_accuracy: 0.9688 - val_precision: 0.9686 - val_recall: 0.9625 - val_auc: 0.9986 - lr: 1.0000e-05
# Epoch 43/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.4328 - categorical_accuracy: 0.8310 - precision: 0.8483 - recall: 0.8138 - auc: 0.9490 - val_loss: 0.1346 - val_categorical_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9989 - lr: 1.0000e-05
# Epoch 44/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.3854 - categorical_accuracy: 0.8372 - precision: 0.8571 - recall: 0.8263 - auc: 0.9594 - val_loss: 0.1272 - val_categorical_accuracy: 0.9688 - val_precision: 0.9748 - val_recall: 0.9688 - val_auc: 0.9992 - lr: 1.0000e-05
# Epoch 45/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3971 - categorical_accuracy: 0.8623 - precision: 0.8732 - recall: 0.8404 - auc: 0.9573 - val_loss: 0.1204 - val_categorical_accuracy: 0.9750 - val_precision: 0.9811 - val_recall: 0.9750 - val_auc: 0.9993 - lr: 1.0000e-05
# Epoch 46/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3338 - categorical_accuracy: 0.8685 - precision: 0.8854 - recall: 0.8466 - auc: 0.9703 - val_loss: 0.1140 - val_categorical_accuracy: 0.9750 - val_precision: 0.9811 - val_recall: 0.9750 - val_auc: 0.9994 - lr: 1.0000e-05
# Epoch 47/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3565 - categorical_accuracy: 0.8607 - precision: 0.8776 - recall: 0.8529 - auc: 0.9653 - val_loss: 0.1079 - val_categorical_accuracy: 0.9812 - val_precision: 0.9873 - val_recall: 0.9750 - val_auc: 0.9996 - lr: 1.0000e-05
# Epoch 48/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3037 - categorical_accuracy: 0.8858 - precision: 0.9031 - recall: 0.8748 - auc: 0.9743 - val_loss: 0.1024 - val_categorical_accuracy: 0.9812 - val_precision: 0.9937 - val_recall: 0.9812 - val_auc: 0.9997 - lr: 1.0000e-05
# Epoch 49/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.3146 - categorical_accuracy: 0.8779 - precision: 0.8919 - recall: 0.8654 - auc: 0.9730 - val_loss: 0.0975 - val_categorical_accuracy: 0.9875 - val_precision: 0.9937 - val_recall: 0.9875 - val_auc: 0.9998 - lr: 1.0000e-05
# Epoch 50/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.3498 - categorical_accuracy: 0.8623 - precision: 0.8782 - recall: 0.8466 - auc: 0.9661 - val_loss: 0.0925 - val_categorical_accuracy: 0.9875 - val_precision: 0.9937 - val_recall: 0.9875 - val_auc: 0.9998 - lr: 1.0000e-05
# Epoch 51/100
# 10/10 [==============================] - 2s 131ms/step - loss: 0.2958 - categorical_accuracy: 0.8858 - precision: 0.8994 - recall: 0.8670 - auc: 0.9773 - val_loss: 0.0878 - val_categorical_accuracy: 0.9937 - val_precision: 0.9937 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 52/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.2793 - categorical_accuracy: 0.9045 - precision: 0.9211 - recall: 0.8951 - auc: 0.9785 - val_loss: 0.0834 - val_categorical_accuracy: 0.9937 - val_precision: 0.9937 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 53/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.3123 - categorical_accuracy: 0.8764 - precision: 0.8885 - recall: 0.8607 - auc: 0.9738 - val_loss: 0.0793 - val_categorical_accuracy: 0.9937 - val_precision: 0.9937 - val_recall: 0.9875 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 54/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3309 - categorical_accuracy: 0.8858 - precision: 0.8960 - recall: 0.8764 - auc: 0.9698 - val_loss: 0.0753 - val_categorical_accuracy: 0.9937 - val_precision: 0.9937 - val_recall: 0.9875 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 55/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.2648 - categorical_accuracy: 0.9077 - precision: 0.9236 - recall: 0.8889 - auc: 0.9816 - val_loss: 0.0716 - val_categorical_accuracy: 0.9937 - val_precision: 0.9937 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 56/100
# 10/10 [==============================] - 2s 122ms/step - loss: 0.2460 - categorical_accuracy: 0.9233 - precision: 0.9339 - recall: 0.9061 - auc: 0.9837 - val_loss: 0.0685 - val_categorical_accuracy: 0.9937 - val_precision: 0.9937 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 57/100
# 10/10 [==============================] - 2s 128ms/step - loss: 0.2494 - categorical_accuracy: 0.9108 - precision: 0.9283 - recall: 0.8920 - auc: 0.9836 - val_loss: 0.0655 - val_categorical_accuracy: 0.9937 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 58/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.2571 - categorical_accuracy: 0.9155 - precision: 0.9303 - recall: 0.8983 - auc: 0.9827 - val_loss: 0.0652 - val_categorical_accuracy: 0.9937 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 59/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.2467 - categorical_accuracy: 0.9014 - precision: 0.9252 - recall: 0.8905 - auc: 0.9844 - val_loss: 0.0649 - val_categorical_accuracy: 0.9937 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 60/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.2441 - categorical_accuracy: 0.9139 - precision: 0.9203 - recall: 0.9030 - auc: 0.9850 - val_loss: 0.0646 - val_categorical_accuracy: 0.9937 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 61/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.2568 - categorical_accuracy: 0.9030 - precision: 0.9085 - recall: 0.8858 - auc: 0.9820 - val_loss: 0.0643 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 62/100
# 10/10 [==============================] - 2s 131ms/step - loss: 0.2442 - categorical_accuracy: 0.9077 - precision: 0.9211 - recall: 0.8951 - auc: 0.9853 - val_loss: 0.0642 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-07
# Epoch 63/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.2271 - categorical_accuracy: 0.9280 - precision: 0.9350 - recall: 0.9233 - auc: 0.9871 - val_loss: 0.0642 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-07
# Epoch 63: early stopping
#
# Logged the following variables:
# ------------------------------
# val_categorical_accuracy: 1.00
# val_precision: 1.00
# val_recall: 0.99
# val_auc: 1.00
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0417 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#           Fold 0.1 Results
# **|------------------------------|**
#   |       Accuracy = 1.000       |
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
#
# Starting Training on Inner Fold 3/5.
# ===========================================
# Epoch 1/100
# 10/10 [==============================] - 7s 289ms/step - loss: 1.1262 - categorical_accuracy: 0.5383 - precision: 0.5556 - recall: 0.5008 - auc: 0.7203 - val_loss: 0.4347 - val_categorical_accuracy: 0.8750 - val_precision: 0.8947 - val_recall: 0.8500 - val_auc: 0.9627 - lr: 1.0000e-05
# Epoch 2/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.9829 - categorical_accuracy: 0.5994 - precision: 0.6285 - recall: 0.5587 - auc: 0.7770 - val_loss: 0.3852 - val_categorical_accuracy: 0.9000 - val_precision: 0.9020 - val_recall: 0.8625 - val_auc: 0.9731 - lr: 1.0000e-05
# Epoch 3/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.9206 - categorical_accuracy: 0.6166 - precision: 0.6372 - recall: 0.5743 - auc: 0.7934 - val_loss: 0.3413 - val_categorical_accuracy: 0.9187 - val_precision: 0.9272 - val_recall: 0.8750 - val_auc: 0.9812 - lr: 1.0000e-05
# Epoch 4/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.8903 - categorical_accuracy: 0.6275 - precision: 0.6452 - recall: 0.5947 - auc: 0.8119 - val_loss: 0.3025 - val_categorical_accuracy: 0.9312 - val_precision: 0.9423 - val_recall: 0.9187 - val_auc: 0.9872 - lr: 1.0000e-05
# Epoch 5/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.8769 - categorical_accuracy: 0.6009 - precision: 0.6301 - recall: 0.5571 - auc: 0.8082 - val_loss: 0.2671 - val_categorical_accuracy: 0.9438 - val_precision: 0.9494 - val_recall: 0.9375 - val_auc: 0.9916 - lr: 1.0000e-05
# Epoch 6/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.7405 - categorical_accuracy: 0.6901 - precision: 0.7136 - recall: 0.6667 - auc: 0.8579 - val_loss: 0.2368 - val_categorical_accuracy: 0.9563 - val_precision: 0.9684 - val_recall: 0.9563 - val_auc: 0.9942 - lr: 1.0000e-05
# Epoch 7/100
# 10/10 [==============================] - 2s 128ms/step - loss: 0.6645 - categorical_accuracy: 0.7214 - precision: 0.7399 - recall: 0.6854 - auc: 0.8831 - val_loss: 0.2110 - val_categorical_accuracy: 0.9625 - val_precision: 0.9686 - val_recall: 0.9625 - val_auc: 0.9962 - lr: 1.0000e-05
# Epoch 8/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.6108 - categorical_accuracy: 0.7559 - precision: 0.7907 - recall: 0.7152 - auc: 0.8989 - val_loss: 0.1887 - val_categorical_accuracy: 0.9688 - val_precision: 0.9686 - val_recall: 0.9625 - val_auc: 0.9976 - lr: 1.0000e-05
# Epoch 9/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.6023 - categorical_accuracy: 0.7387 - precision: 0.7640 - recall: 0.7042 - auc: 0.9026 - val_loss: 0.1687 - val_categorical_accuracy: 0.9688 - val_precision: 0.9747 - val_recall: 0.9625 - val_auc: 0.9982 - lr: 1.0000e-05
# Epoch 10/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.5600 - categorical_accuracy: 0.7778 - precision: 0.7869 - recall: 0.7512 - auc: 0.9150 - val_loss: 0.1513 - val_categorical_accuracy: 0.9812 - val_precision: 0.9811 - val_recall: 0.9750 - val_auc: 0.9989 - lr: 1.0000e-05
# Epoch 11/100
# 10/10 [==============================] - 2s 131ms/step - loss: 0.4763 - categorical_accuracy: 0.8106 - precision: 0.8237 - recall: 0.7825 - auc: 0.9378 - val_loss: 0.1365 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9993 - lr: 1.0000e-05
# Epoch 12/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.4224 - categorical_accuracy: 0.8419 - precision: 0.8560 - recall: 0.8185 - auc: 0.9515 - val_loss: 0.1237 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9996 - lr: 1.0000e-05
# Epoch 13/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.4176 - categorical_accuracy: 0.8482 - precision: 0.8618 - recall: 0.8294 - auc: 0.9527 - val_loss: 0.1123 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9996 - lr: 1.0000e-05
# Epoch 14/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.4222 - categorical_accuracy: 0.8279 - precision: 0.8489 - recall: 0.8091 - auc: 0.9504 - val_loss: 0.1020 - val_categorical_accuracy: 0.9812 - val_precision: 0.9874 - val_recall: 0.9812 - val_auc: 0.9998 - lr: 1.0000e-05
# Epoch 15/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3800 - categorical_accuracy: 0.8529 - precision: 0.8686 - recall: 0.8279 - auc: 0.9613 - val_loss: 0.0927 - val_categorical_accuracy: 0.9812 - val_precision: 0.9874 - val_recall: 0.9812 - val_auc: 0.9998 - lr: 1.0000e-05
# Epoch 16/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3351 - categorical_accuracy: 0.8654 - precision: 0.8746 - recall: 0.8513 - auc: 0.9700 - val_loss: 0.0846 - val_categorical_accuracy: 0.9812 - val_precision: 0.9874 - val_recall: 0.9812 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 17/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.3686 - categorical_accuracy: 0.8560 - precision: 0.8620 - recall: 0.8310 - auc: 0.9617 - val_loss: 0.0772 - val_categorical_accuracy: 0.9875 - val_precision: 0.9874 - val_recall: 0.9812 - val_auc: 0.9999 - lr: 1.0000e-05
# Epoch 18/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3540 - categorical_accuracy: 0.8592 - precision: 0.8744 - recall: 0.8498 - auc: 0.9645 - val_loss: 0.0705 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 0.9937 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 19/100
# 10/10 [==============================] - 2s 123ms/step - loss: 0.3245 - categorical_accuracy: 0.8826 - precision: 0.8937 - recall: 0.8685 - auc: 0.9712 - val_loss: 0.0644 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 20/100
# 10/10 [==============================] - 2s 130ms/step - loss: 0.2496 - categorical_accuracy: 0.9186 - precision: 0.9318 - recall: 0.8983 - auc: 0.9864 - val_loss: 0.0593 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 21/100
# 10/10 [==============================] - 2s 128ms/step - loss: 0.2567 - categorical_accuracy: 0.9045 - precision: 0.9137 - recall: 0.8951 - auc: 0.9842 - val_loss: 0.0546 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 22/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.2690 - categorical_accuracy: 0.9045 - precision: 0.9180 - recall: 0.8936 - auc: 0.9811 - val_loss: 0.0504 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 23/100
# 10/10 [==============================] - 2s 133ms/step - loss: 0.2257 - categorical_accuracy: 0.9186 - precision: 0.9342 - recall: 0.9108 - auc: 0.9882 - val_loss: 0.0467 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 24/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.2657 - categorical_accuracy: 0.9045 - precision: 0.9081 - recall: 0.8967 - auc: 0.9805 - val_loss: 0.0431 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 25/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.2277 - categorical_accuracy: 0.9155 - precision: 0.9249 - recall: 0.9061 - auc: 0.9875 - val_loss: 0.0398 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 26/100
# 10/10 [==============================] - 2s 167ms/step - loss: 0.2062 - categorical_accuracy: 0.9343 - precision: 0.9391 - recall: 0.9171 - auc: 0.9914 - val_loss: 0.0369 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-05
# Epoch 27/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.2057 - categorical_accuracy: 0.9264 - precision: 0.9361 - recall: 0.9171 - auc: 0.9903 - val_loss: 0.0366 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 28/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.1958 - categorical_accuracy: 0.9343 - precision: 0.9352 - recall: 0.9264 - auc: 0.9905 - val_loss: 0.0364 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 29/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.2203 - categorical_accuracy: 0.9218 - precision: 0.9295 - recall: 0.9077 - auc: 0.9878 - val_loss: 0.0361 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 30/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.2090 - categorical_accuracy: 0.9327 - precision: 0.9409 - recall: 0.9218 - auc: 0.9895 - val_loss: 0.0359 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-06
# Epoch 31/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.1722 - categorical_accuracy: 0.9468 - precision: 0.9523 - recall: 0.9374 - auc: 0.9945 - val_loss: 0.0358 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-07
# Epoch 32/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.1905 - categorical_accuracy: 0.9484 - precision: 0.9552 - recall: 0.9343 - auc: 0.9922 - val_loss: 0.0358 - val_categorical_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-07
# Epoch 32: early stopping
#
# Logged the following variables:
# ------------------------------
# val_categorical_accuracy: 1.00
# val_precision: 1.00
# val_recall: 1.00
# val_auc: 1.00
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0163 - categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000
#           Fold 0.2 Results
# **|------------------------------|**
#   |       Accuracy = 1.000       |
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# ...
# Epoch 16/100
# 10/10 [==============================] - 2s 148ms/step - loss: 1.7104 - categorical_accuracy: 0.3891 - precision: 0.3847 - recall: 0.3625 - auc: 0.5829 - val_loss: 1.0140 - val_categorical_accuracy: 0.5688 - val_precision: 0.5723 - val_recall: 0.5688 - val_auc: 0.7660 - lr: 1.0000e-05
# Epoch 17/100
# 10/10 [==============================] - 2s 142ms/step - loss: 1.6580 - categorical_accuracy: 0.3719 - precision: 0.3785 - recall: 0.3625 - auc: 0.6135 - val_loss: 0.9410 - val_categorical_accuracy: 0.6375 - val_precision: 0.6392 - val_recall: 0.6313 - val_auc: 0.7930 - lr: 1.0000e-05
# Epoch 18/100
# 10/10 [==============================] - 2s 127ms/step - loss: 1.5929 - categorical_accuracy: 0.4125 - precision: 0.4169 - recall: 0.3922 - auc: 0.6252 - val_loss: 0.8740 - val_categorical_accuracy: 0.6812 - val_precision: 0.6812 - val_recall: 0.6812 - val_auc: 0.8148 - lr: 1.0000e-05
# Epoch 19/100
# 10/10 [==============================] - 2s 141ms/step - loss: 1.4810 - categorical_accuracy: 0.4359 - precision: 0.4298 - recall: 0.3969 - auc: 0.6396 - val_loss: 0.8115 - val_categorical_accuracy: 0.7000 - val_precision: 0.6981 - val_recall: 0.6938 - val_auc: 0.8345 - lr: 1.0000e-05
# Epoch 20/100
# 10/10 [==============================] - 2s 138ms/step - loss: 1.4514 - categorical_accuracy: 0.4484 - precision: 0.4537 - recall: 0.4359 - auc: 0.6651 - val_loss: 0.7544 - val_categorical_accuracy: 0.7125 - val_precision: 0.7170 - val_recall: 0.7125 - val_auc: 0.8519 - lr: 1.0000e-05
# Epoch 21/100
# 10/10 [==============================] - 2s 125ms/step - loss: 1.2930 - categorical_accuracy: 0.4969 - precision: 0.5067 - recall: 0.4734 - auc: 0.6987 - val_loss: 0.7018 - val_categorical_accuracy: 0.7312 - val_precision: 0.7278 - val_recall: 0.7188 - val_auc: 0.8683 - lr: 1.0000e-05
# Epoch 22/100
# 10/10 [==============================] - 2s 141ms/step - loss: 1.3563 - categorical_accuracy: 0.4563 - precision: 0.4585 - recall: 0.4313 - auc: 0.6808 - val_loss: 0.6530 - val_categorical_accuracy: 0.7437 - val_precision: 0.7437 - val_recall: 0.7437 - val_auc: 0.8843 - lr: 1.0000e-05
# Epoch 23/100
# 10/10 [==============================] - 2s 124ms/step - loss: 1.2058 - categorical_accuracy: 0.5094 - precision: 0.5176 - recall: 0.4812 - auc: 0.7238 - val_loss: 0.6073 - val_categorical_accuracy: 0.7625 - val_precision: 0.7595 - val_recall: 0.7500 - val_auc: 0.8986 - lr: 1.0000e-05
# Epoch 24/100
# 10/10 [==============================] - 2s 132ms/step - loss: 1.0968 - categorical_accuracy: 0.5281 - precision: 0.5354 - recall: 0.5078 - auc: 0.7485 - val_loss: 0.5661 - val_categorical_accuracy: 0.7750 - val_precision: 0.7799 - val_recall: 0.7750 - val_auc: 0.9103 - lr: 1.0000e-05
# Epoch 25/100
# 10/10 [==============================] - 2s 124ms/step - loss: 1.1079 - categorical_accuracy: 0.5641 - precision: 0.5669 - recall: 0.5359 - auc: 0.7559 - val_loss: 0.5271 - val_categorical_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.9223 - lr: 1.0000e-05
# Epoch 26/100
# 10/10 [==============================] - 2s 131ms/step - loss: 1.0993 - categorical_accuracy: 0.5484 - precision: 0.5565 - recall: 0.5234 - auc: 0.7580 - val_loss: 0.4916 - val_categorical_accuracy: 0.7875 - val_precision: 0.7875 - val_recall: 0.7875 - val_auc: 0.9329 - lr: 1.0000e-05
# Epoch 27/100
# 10/10 [==============================] - 2s 125ms/step - loss: 1.0107 - categorical_accuracy: 0.5734 - precision: 0.5880 - recall: 0.5531 - auc: 0.7815 - val_loss: 0.4582 - val_categorical_accuracy: 0.7937 - val_precision: 0.7937 - val_recall: 0.7937 - val_auc: 0.9412 - lr: 1.0000e-05
# Epoch 28/100
# 10/10 [==============================] - 2s 127ms/step - loss: 0.9937 - categorical_accuracy: 0.5969 - precision: 0.6082 - recall: 0.5797 - auc: 0.7940 - val_loss: 0.4278 - val_categorical_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.9492 - lr: 1.0000e-05
# Epoch 29/100
# 10/10 [==============================] - 2s 130ms/step - loss: 0.9939 - categorical_accuracy: 0.5875 - precision: 0.5913 - recall: 0.5719 - auc: 0.7935 - val_loss: 0.3993 - val_categorical_accuracy: 0.8125 - val_precision: 0.8176 - val_recall: 0.8125 - val_auc: 0.9556 - lr: 1.0000e-05
# Epoch 30/100
# 10/10 [==============================] - 2s 153ms/step - loss: 0.8955 - categorical_accuracy: 0.6234 - precision: 0.6374 - recall: 0.6016 - auc: 0.8198 - val_loss: 0.3727 - val_categorical_accuracy: 0.8313 - val_precision: 0.8344 - val_recall: 0.8188 - val_auc: 0.9624 - lr: 1.0000e-05
# Epoch 31/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.8961 - categorical_accuracy: 0.6156 - precision: 0.6228 - recall: 0.5984 - auc: 0.8203 - val_loss: 0.3482 - val_categorical_accuracy: 0.8375 - val_precision: 0.8481 - val_recall: 0.8375 - val_auc: 0.9665 - lr: 1.0000e-05
# Epoch 32/100
# 10/10 [==============================] - 2s 136ms/step - loss: 0.8228 - categorical_accuracy: 0.6313 - precision: 0.6453 - recall: 0.5969 - auc: 0.8385 - val_loss: 0.3256 - val_categorical_accuracy: 0.8438 - val_precision: 0.8535 - val_recall: 0.8375 - val_auc: 0.9712 - lr: 1.0000e-05
# Epoch 33/100
# 10/10 [==============================] - 2s 140ms/step - loss: 0.7956 - categorical_accuracy: 0.6672 - precision: 0.6722 - recall: 0.6375 - auc: 0.8489 - val_loss: 0.3044 - val_categorical_accuracy: 0.8500 - val_precision: 0.8553 - val_recall: 0.8500 - val_auc: 0.9747 - lr: 1.0000e-05
# Epoch 34/100
# 10/10 [==============================] - 2s 139ms/step - loss: 0.8129 - categorical_accuracy: 0.6578 - precision: 0.6743 - recall: 0.6406 - auc: 0.8480 - val_loss: 0.2848 - val_categorical_accuracy: 0.8687 - val_precision: 0.8679 - val_recall: 0.8625 - val_auc: 0.9778 - lr: 1.0000e-05
# Epoch 35/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.7549 - categorical_accuracy: 0.6797 - precision: 0.6890 - recall: 0.6578 - auc: 0.8624 - val_loss: 0.2666 - val_categorical_accuracy: 0.8687 - val_precision: 0.8679 - val_recall: 0.8625 - val_auc: 0.9803 - lr: 1.0000e-05
# Epoch 36/100
# 10/10 [==============================] - 2s 127ms/step - loss: 0.7329 - categorical_accuracy: 0.6984 - precision: 0.7081 - recall: 0.6859 - auc: 0.8711 - val_loss: 0.2498 - val_categorical_accuracy: 0.8813 - val_precision: 0.8924 - val_recall: 0.8813 - val_auc: 0.9827 - lr: 1.0000e-05
# Epoch 37/100
# 10/10 [==============================] - 2s 144ms/step - loss: 0.6955 - categorical_accuracy: 0.7219 - precision: 0.7270 - recall: 0.7031 - auc: 0.8818 - val_loss: 0.2343 - val_categorical_accuracy: 0.8875 - val_precision: 0.8981 - val_recall: 0.8813 - val_auc: 0.9846 - lr: 1.0000e-05
# Epoch 38/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.7028 - categorical_accuracy: 0.7031 - precision: 0.7080 - recall: 0.6781 - auc: 0.8769 - val_loss: 0.2196 - val_categorical_accuracy: 0.8875 - val_precision: 0.8987 - val_recall: 0.8875 - val_auc: 0.9865 - lr: 1.0000e-05
# Epoch 39/100
# 10/10 [==============================] - 2s 132ms/step - loss: 0.6487 - categorical_accuracy: 0.7188 - precision: 0.7274 - recall: 0.7047 - auc: 0.8952 - val_loss: 0.2056 - val_categorical_accuracy: 0.9125 - val_precision: 0.9177 - val_recall: 0.9062 - val_auc: 0.9885 - lr: 1.0000e-05
# Epoch 40/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.6588 - categorical_accuracy: 0.7297 - precision: 0.7356 - recall: 0.7172 - auc: 0.8906 - val_loss: 0.1929 - val_categorical_accuracy: 0.9125 - val_precision: 0.9182 - val_recall: 0.9125 - val_auc: 0.9899 - lr: 1.0000e-05
# Epoch 41/100
# 10/10 [==============================] - 2s 127ms/step - loss: 0.5390 - categorical_accuracy: 0.7766 - precision: 0.7815 - recall: 0.7656 - auc: 0.9207 - val_loss: 0.1811 - val_categorical_accuracy: 0.9187 - val_precision: 0.9182 - val_recall: 0.9125 - val_auc: 0.9917 - lr: 1.0000e-05
# Epoch 42/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.5924 - categorical_accuracy: 0.7437 - precision: 0.7565 - recall: 0.7281 - auc: 0.9081 - val_loss: 0.1701 - val_categorical_accuracy: 0.9187 - val_precision: 0.9299 - val_recall: 0.9125 - val_auc: 0.9931 - lr: 1.0000e-05
# Epoch 43/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.5016 - categorical_accuracy: 0.7875 - precision: 0.7943 - recall: 0.7781 - auc: 0.9307 - val_loss: 0.1602 - val_categorical_accuracy: 0.9250 - val_precision: 0.9299 - val_recall: 0.9125 - val_auc: 0.9938 - lr: 1.0000e-05
# Epoch 44/100
# 10/10 [==============================] - 2s 149ms/step - loss: 0.4806 - categorical_accuracy: 0.8125 - precision: 0.8192 - recall: 0.8000 - auc: 0.9357 - val_loss: 0.1511 - val_categorical_accuracy: 0.9500 - val_precision: 0.9490 - val_recall: 0.9312 - val_auc: 0.9948 - lr: 1.0000e-05
# Epoch 45/100
# 10/10 [==============================] - 2s 124ms/step - loss: 0.5351 - categorical_accuracy: 0.7750 - precision: 0.7827 - recall: 0.7656 - auc: 0.9239 - val_loss: 0.1422 - val_categorical_accuracy: 0.9500 - val_precision: 0.9560 - val_recall: 0.9500 - val_auc: 0.9954 - lr: 1.0000e-05
# Epoch 46/100
# 10/10 [==============================] - 2s 136ms/step - loss: 0.4713 - categorical_accuracy: 0.7828 - precision: 0.7933 - recall: 0.7734 - auc: 0.9378 - val_loss: 0.1341 - val_categorical_accuracy: 0.9500 - val_precision: 0.9560 - val_recall: 0.9500 - val_auc: 0.9961 - lr: 1.0000e-05
# Epoch 47/100
# 10/10 [==============================] - 2s 136ms/step - loss: 0.4401 - categorical_accuracy: 0.8141 - precision: 0.8240 - recall: 0.8047 - auc: 0.9451 - val_loss: 0.1266 - val_categorical_accuracy: 0.9563 - val_precision: 0.9620 - val_recall: 0.9500 - val_auc: 0.9967 - lr: 1.0000e-05
# Epoch 48/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.4512 - categorical_accuracy: 0.8094 - precision: 0.8157 - recall: 0.7953 - auc: 0.9436 - val_loss: 0.1196 - val_categorical_accuracy: 0.9625 - val_precision: 0.9623 - val_recall: 0.9563 - val_auc: 0.9971 - lr: 1.0000e-05
# Epoch 49/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.4123 - categorical_accuracy: 0.8219 - precision: 0.8212 - recall: 0.8109 - auc: 0.9516 - val_loss: 0.1130 - val_categorical_accuracy: 0.9625 - val_precision: 0.9625 - val_recall: 0.9625 - val_auc: 0.9975 - lr: 1.0000e-05
# Epoch 50/100
# 10/10 [==============================] - 2s 140ms/step - loss: 0.4055 - categorical_accuracy: 0.8297 - precision: 0.8411 - recall: 0.8188 - auc: 0.9529 - val_loss: 0.1068 - val_categorical_accuracy: 0.9625 - val_precision: 0.9686 - val_recall: 0.9625 - val_auc: 0.9978 - lr: 1.0000e-05
# Epoch 51/100
# 10/10 [==============================] - 2s 149ms/step - loss: 0.3674 - categorical_accuracy: 0.8484 - precision: 0.8569 - recall: 0.8422 - auc: 0.9614 - val_loss: 0.1013 - val_categorical_accuracy: 0.9750 - val_precision: 0.9810 - val_recall: 0.9688 - val_auc: 0.9981 - lr: 1.0000e-05
# Epoch 52/100
# 10/10 [==============================] - 2s 125ms/step - loss: 0.3971 - categorical_accuracy: 0.8375 - precision: 0.8421 - recall: 0.8250 - auc: 0.9558 - val_loss: 0.0959 - val_categorical_accuracy: 0.9750 - val_precision: 0.9810 - val_recall: 0.9688 - val_auc: 0.9983 - lr: 1.0000e-05
# Epoch 53/100
# 10/10 [==============================] - 2s 137ms/step - loss: 0.3860 - categorical_accuracy: 0.8391 - precision: 0.8528 - recall: 0.8328 - auc: 0.9570 - val_loss: 0.0908 - val_categorical_accuracy: 0.9812 - val_precision: 0.9811 - val_recall: 0.9750 - val_auc: 0.9985 - lr: 1.0000e-05
# Epoch 54/100
# 10/10 [==============================] - 2s 138ms/step - loss: 0.3298 - categorical_accuracy: 0.8547 - precision: 0.8746 - recall: 0.8500 - auc: 0.9689 - val_loss: 0.0861 - val_categorical_accuracy: 0.9812 - val_precision: 0.9812 - val_recall: 0.9812 - val_auc: 0.9988 - lr: 1.0000e-05
# Epoch 55/100
# 10/10 [==============================] - 2s 145ms/step - loss: 0.3244 - categorical_accuracy: 0.8625 - precision: 0.8726 - recall: 0.8562 - auc: 0.9696 - val_loss: 0.0818 - val_categorical_accuracy: 0.9812 - val_precision: 0.9874 - val_recall: 0.9812 - val_auc: 0.9990 - lr: 1.0000e-05
# Epoch 56/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.3093 - categorical_accuracy: 0.8687 - precision: 0.8794 - recall: 0.8547 - auc: 0.9727 - val_loss: 0.0778 - val_categorical_accuracy: 0.9875 - val_precision: 0.9874 - val_recall: 0.9812 - val_auc: 0.9991 - lr: 1.0000e-05
# Epoch 57/100
# 10/10 [==============================] - 2s 141ms/step - loss: 0.3023 - categorical_accuracy: 0.8719 - precision: 0.8772 - recall: 0.8594 - auc: 0.9735 - val_loss: 0.0740 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9992 - lr: 1.0000e-05
# Epoch 58/100
# 10/10 [==============================] - 2s 127ms/step - loss: 0.3017 - categorical_accuracy: 0.8687 - precision: 0.8786 - recall: 0.8594 - auc: 0.9745 - val_loss: 0.0704 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9994 - lr: 1.0000e-05
# Epoch 59/100
# 10/10 [==============================] - 2s 126ms/step - loss: 0.3381 - categorical_accuracy: 0.8469 - precision: 0.8519 - recall: 0.8359 - auc: 0.9672 - val_loss: 0.0669 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9994 - lr: 1.0000e-05
# Epoch 60/100
# 10/10 [==============================] - 2s 145ms/step - loss: 0.2868 - categorical_accuracy: 0.8781 - precision: 0.8843 - recall: 0.8719 - auc: 0.9764 - val_loss: 0.0635 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9996 - lr: 1.0000e-05
# Epoch 61/100
# 10/10 [==============================] - 2s 138ms/step - loss: 0.2895 - categorical_accuracy: 0.8891 - precision: 0.8927 - recall: 0.8844 - auc: 0.9762 - val_loss: 0.0604 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9996 - lr: 1.0000e-05
# Epoch 62/100
# 10/10 [==============================] - 2s 146ms/step - loss: 0.2905 - categorical_accuracy: 0.8766 - precision: 0.8854 - recall: 0.8687 - auc: 0.9758 - val_loss: 0.0575 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9997 - lr: 1.0000e-05
# Epoch 63/100
# 10/10 [==============================] - 2s 138ms/step - loss: 0.2476 - categorical_accuracy: 0.8891 - precision: 0.8956 - recall: 0.8844 - auc: 0.9830 - val_loss: 0.0548 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9997 - lr: 1.0000e-05
# Epoch 64/100
# 10/10 [==============================] - 2s 131ms/step - loss: 0.2668 - categorical_accuracy: 0.8781 - precision: 0.8859 - recall: 0.8734 - auc: 0.9798 - val_loss: 0.0522 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9998 - lr: 1.0000e-05
# Epoch 65/100
# 10/10 [==============================] - 2s 129ms/step - loss: 0.2815 - categorical_accuracy: 0.8875 - precision: 0.8933 - recall: 0.8766 - auc: 0.9776 - val_loss: 0.0519 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9998 - lr: 1.0000e-06
# Epoch 66/100
# 10/10 [==============================] - 2s 128ms/step - loss: 0.2511 - categorical_accuracy: 0.9047 - precision: 0.9085 - recall: 0.9000 - auc: 0.9824 - val_loss: 0.0517 - val_categorical_accuracy: 0.9875 - val_precision: 0.9875 - val_recall: 0.9875 - val_auc: 0.9998 - lr: 1.0000e-06
# Epoch 66: early stopping
#
# Logged the following variables:
# ------------------------------
# val_categorical_accuracy: 0.99
# val_precision: 0.99
# val_recall: 0.99
# val_auc: 1.00
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1264 - categorical_accuracy: 0.9762 - precision: 0.9756 - recall: 0.9524 - auc: 0.9994
#           Fold 19.4 Results
# **|------------------------------|**
#   |       Accuracy = 0.976       |
#
#             Fold 19 Averaged Results
# **|----------------------------------------|**
#   |          Mean Accuracy = 0.976         |
#   |      Mean Standard Deviation = 0.000   |

# %%
loss, categorical_accuracy, precision, recall, auc = model.evaluate(test)
# Out:
# 1/1 [==============================] - 0s 295ms/step - loss: 0.1264 - categorical_accuracy: 0.9762 - precision: 0.9756 - recall: 0.9524 - auc: 0.9994
